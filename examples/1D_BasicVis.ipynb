# %% [markdown]
# # 1D - BasicVis
#
# This notebook contains an index of common visualizations implemented in Oloren
# Chem Engine.
#
# First, we'll create example model, dataset, and representation objects for use
# in creating this index.

# %%
import olorenchemengine as oce

# We'll use a dataset of BACE (beta secretase enzyme) pIC50 values for this
# from a collection put together by MoleculeNet
dataset = oce.BACEDataset() + oce.ScaffoldSplit()
model = oce.BaseBoosting([oce.RandomForestModel(oce.DescriptastorusDescriptor("morgan3counts")),
                         oce.RandomForestModel(oce.OlorenCheckpoint("default"))])
model.fit(*dataset.train_dataset)

# %% [markdown]
# ## Visualizing the chemical space of a dataset
#
# Useful for exploratory data analysis, e.g. seeing if most compounds are similar
# or different, if there are clear subsets of compounds etc.

# %%
vis = oce.ChemicalSpacePlot(dataset, oce.DescriptastorusDescriptor("morgan3counts"), opacity = 0.4, dim_reduction = "tsne")
vis.render_ipynb()

for i in range(20):
    vis.upload_oas()
# Out:
# Uploaded visualization to https://oas.oloren.ai/vis?vid=5blmud8dnWO4YSkpuL9W
# Uploaded visualization to https://oas.oloren.ai/vis?vid=wfGLsLIWdUx0fAgGq5e9
# Uploaded visualization to https://oas.oloren.ai/vis?vid=ItbtRVHLdJDcdv8nsSV4
# Uploaded visualization to https://oas.oloren.ai/vis?vid=mE03hLsf9EneBz78KiNv
# Uploaded visualization to https://oas.oloren.ai/vis?vid=BnCAdXkDH4UymfBS0lzu
# Uploaded visualization to https://oas.oloren.ai/vis?vid=5ZLR7fYhC7glX2CoWO4S
# Uploaded visualization to https://oas.oloren.ai/vis?vid=Yh5gdNDtMxDbOX53OypA
# Uploaded visualization to https://oas.oloren.ai/vis?vid=D1pspGBNfJrwu2qKzCCA
# Uploaded visualization to https://oas.oloren.ai/vis?vid=QwxfbzqkTRcNuzvKGhlC
# Uploaded visualization to https://oas.oloren.ai/vis?vid=rimrmfroihrsGYV9MkMu
# Uploaded visualization to https://oas.oloren.ai/vis?vid=UBJ1eYqPFlxyRrD0zLEX
# Uploaded visualization to https://oas.oloren.ai/vis?vid=9zljjQv3ycgBqU6NfmY5
# Uploaded visualization to https://oas.oloren.ai/vis?vid=ef2DB3ExDJQFY0ptG79h
# Uploaded visualization to https://oas.oloren.ai/vis?vid=O7R4tjsuO78SOjrfCpCI
# Uploaded visualization to https://oas.oloren.ai/vis?vid=DlJNR08L2KNLrsouFchO
# Uploaded visualization to https://oas.oloren.ai/vis?vid=hmcqqJFVRtv17PWNaVsr
# Uploaded visualization to https://oas.oloren.ai/vis?vid=TdXQ4vOIFfsn1nvV6klE
# Uploaded visualization to https://oas.oloren.ai/vis?vid=fE1udo9Z5ZO0uOg6XyCY
# Uploaded visualization to https://oas.oloren.ai/vis?vid=474amIpanyUTfefLQhFi
# Uploaded visualization to https://oas.oloren.ai/vis?vid=bAAeHLa2tXeqXnRp5TIj

# %% [markdown]
# ## Visualizing model errors by cluster
#
# There is an additional visualization which does the chemical space plot and then
# graphs onto it a dataset's train/test split via the marker outlines as well as the
# magnitude of the residuals via the size of the markers. This is useful for examining
# model errors and discering potential patterns across cores.

# %%
vis = oce.VisualizeDatasetSplit(dataset, oce.DescriptastorusDescriptor("morgan3counts"), model = model, opacity = 0.4)
vis.render_ipynb()
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="data:text/html,%0A%20%20%20%20%20%20%20%20%3C%21DOCTYPE%20html%3E%0A%20%20%20%20%20%20%20%20%3Chead%3E%0A%20%20%20%20%20%20%20%20%3Cmeta%20charset%3D%22utf-8%22%3E%0A%20%20%20%20%20%20%20%20%3C%2Fhead%3E%0A%0A%20%20%20%20%20%20%20%20%3Chtml%20style%3D%22height%3A%20100%25%3B%22%3E%0A%0A%20%20%20%20%20%20%20%20%3C%21--%20Load%20packages%20--%3E%0A%20%20%20%20%20%20%20%20%3Cscript%20src%3D%22https%3A%2F%2Fcdn.plot.ly%2Fplotly-2.12.1.min.js%22%3E%3C%2Fscript%3E%3Cscript%20src%3D%22https%3A%2F%2Funpkg.com%2Fsmiles-drawer%401.0.10%2Fdist%2Fsmiles-drawer.min.js%22%3E%3C%2Fscript%3E%0A%20%20%20%20%20%20%20%20%3Cbody%20style%3D%22background-color%3A%23FFFFFF%3B%20height%3A%20100%25%3B%22%3E%0A%20%20%20%20%20%20%20%20%3C%21--%20Create%20a%20div%20where%20the%20graph%20will%20take%20place%20--%3E%0A%20%20%20%20%20%20%20%20%3Cdiv%20id%3D%22basevis-entry%22%20data-visdata%3D%22%7B%26quot%3BSMILES%26quot%3B%3A%20%5B%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28C%23CCCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DCC%28C%23CCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DCC%28C%23CCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%28C%23CCCO%29%3DCC%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%28C%23CCCCCO%29%3DCC%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DCC%28OCCC%28F%29F%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCOCC%23CC1%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DCC%3DC1F%26quot%3B%2C%20%26quot%3BCOCC%23CC1%3DCC%28%5BC%40%40%5D2%28C3%3DCC%28C%29%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DCC%3DC1F%26quot%3B%2C%20%26quot%3BCOC%2FC%3DC%2FC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCOCC%2FC%3DC%2FC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCC%23CC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCC%28C%29C%23CC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCOCC%23CC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCOCCC%23CC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BC%5BC%40%40H%5D%28O%29C%23CC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCC1%3DC%28OC%28F%29F%29C%3DCC%28%5BC%40%5D2%28C3%3DCC%3DC%28F%29C%28C%23CCF%29%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCCCCC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DCC%28%2FC%3DC%2FCC%28F%29F%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCCCC%23CC1%3DCC%3DCC%28%5BC%40%40%5D2%28C3%3DCC%3DC%28OC%28F%29F%29C%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29%3DC1%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DCC%28OCC%28F%29F%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29%5BC%40%40%5D%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCC%3DC%28F%29F%29%3DC2% ...

# %% [markdown]
# ## VisualizeFeatures - exploratory data analysis (EDA) tool
#
# This tool allows for the visualization of property correlation with given properties.
# It is compatible with all representations that have names defined for each feature.
# An example is below correlating various features provided in the LipinskiDescriptor
# set from RDKit with the pIC50 value.
#
# Often times, like below, there aren't any strong correlations but weak
# correlations can help provide insight into overall trends and can be combined
# into stronger overall models. Other interesting ways to examine these graphs are
# to examine subsets of the plot (by hovering to see the molecular structure) and
# seeing how those subsets vary or do not vary with changes in property value or
# feature value. This can help determine what is not important as well.

# %%
vis = oce.VisualizeFeatures(dataset, features = [oce.LipinskiDescriptor()])
vis.render_ipynb()
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="data:text/html,%0A%20%20%20%20%20%20%20%20%3C%21DOCTYPE%20html%3E%0A%20%20%20%20%20%20%20%20%3Chead%3E%0A%20%20%20%20%20%20%20%20%3Cmeta%20charset%3D%22utf-8%22%3E%0A%20%20%20%20%20%20%20%20%3C%2Fhead%3E%0A%0A%20%20%20%20%20%20%20%20%3Chtml%20style%3D%22height%3A%20100%25%3B%22%3E%0A%0A%20%20%20%20%20%20%20%20%3C%21--%20Load%20packages%20--%3E%0A%20%20%20%20%20%20%20%20%3Cscript%20src%3D%22https%3A%2F%2Fcdn.plot.ly%2Fplotly-2.12.1.min.js%22%3E%3C%2Fscript%3E%3Cscript%20src%3D%
ref_compound = dataset.data[dataset.structure_col].iloc[42]
vis = oce.VisualizeCounterfactual(ref_compound, model, n=1000, delta=0.1)
vis.render_ipynb()
# Out:
# Downloading swap-mutations/trans_0.json...
# Downloading swap-mutations/trans_1.json...
#  38%|███▊      | 11/29 [00:02<00:03,  5.80it/s]
# Continuing
# 100%|██████████| 29/29 [00:07<00:00,  3.76it/s]
# 100%|██████████| 3217/3217 [00:00<00:00, 3820.76it/s]
# 100%|██████████| 2585/2585 [00:05<00:00, 499.59it/s]
#         <iframe
#             width="800"
#             height="600"
#             src="data:text/html,%0A%20%20%20%20%20%20%20%20%3C%21DOCTYPE%20html%3E%0A%20%20%20%20%20%20%20%20%3Chead%3E%0A%20%20%20%20%20%20%20%20%3Cmeta%20charset%3D%22utf-8%22%3E%0A%20%20%20%20%20%20%20%20%3C%2Fhead%3E%0A%0A%20%20%20%20%20%20%20%20%3Chtml%20style%3D%22height%3A%20100%25%3B%22%3E%0A%0A%20%20%20%20%20%20%20%20%3C%21--%20Load%20packages%20--%3E%0A%20%20%20%20%20%20%20%20%3Cscript%20src%3D%22https%3A%2F%2Fcdn.plot.ly%2Fplotly-2.12.1.min.js%22%3E%3C%2Fscript%3E%3Cscript%20src%3D%22https%3A%2F%2Funpkg.com%2Fsmiles-drawer%401.0.10%2Fdist%2Fsmiles-drawer.min.js%22%3E%3C%2Fscript%3E%0A%20%20%20%20%20%20%20%20%3Cbody%20style%3D%22background-color%3A%23FFFFFF%3B%20height%3A%20100%25%3B%22%3E%0A%20%20%20%20%20%20%20%20%3C%21--%20Create%20a%20div%20where%20the%20graph%20will%20take%20place%20--%3E%0A%20%20%20%20%20%20%20%20%3Cdiv%20id%3D%22basevis-entry%22%20data-visdata%3D%22%7B%26quot%3BSMILES%26quot%3B%3A%20%5B%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28O%29C%28OCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BNC1%3DNC%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29C%28%3DO%29N1Br%26quot%3B%2C%20%26quot%3BCN1C%28%3D%5BOH%2B%5D%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCC%28C%29OC1%3DCC%3DC%28C2%28C3%3DCC%3DC%28F%29C%28OCCF%29%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29C%3DC1%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29N%3DC1CCl%26quot%3B%2C%20%26quot%3BCS%28%3DO%29%28%3DO%29N1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCC%28Cl%29%28Cl%29Cl%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DC%28F%29C%3DCC%28OCCF%29%3DC2O%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%28OCCF%29%3DC%28F%29C%3DN2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29%28C2%3DCC%3DC%28OC%28F%29F%29C%3DN2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29%5BO%2B%5D%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%3DNC%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29C1%3DO%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%5BS-%5D%29N%3DC1N%26quot%3B%2C%20%26quot%3BCNC1%3DCC%3DC%28C2%28C3%3DCC%3DC%28F%29C%28OCCF%29%3DC3%29N%3DC%28N%29N%28C%29C2%3DO%29C%3DC1%26quot%3B%2C%20%26quot%3BCN1C%28N%29%3DNC%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29S1%3DO%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28C%28%3DO%29SCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28SC%28F%29%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29%28C2%3DCC%3DC%28N%29%5BN%2B%5D%28C%28F%29F%29%3DC2%29N%3DC1N%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29%28C2%3DCC%3DCC%28N%29%3DC2OC%28F%29F%29N%3DC1N%26quot%3B%2C%20%26quot%3BNC1%3DNC%28C2%3DCC%3DC%28OC%28F%29F%29C%3DC2%29%28C2%3DCC%3DC%28F%29C%28OCCF%29%3DC2%29C%28%3DO%29C1C%28F%29%28F%29F%26quot%3B%2C%20%26quot%3BCN1C%28O%29%3DNC%28%3DO%29C1%28C1%3DCC%3DC%28OC%28F%29F%29C%3DC1%29C1%3DCC%3DC%28F%29C%28OCCF%29%3DC1%26quot%3B%2C%20%26quot%3BCN1C%28%3DO%29C%28C2%3DCC% ...
